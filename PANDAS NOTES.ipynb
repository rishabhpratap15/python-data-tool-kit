# %% [markdown]
# #Defination
# pandas is a fast,powerful,flexible and easy to use open source data analysis and manipulation tool built on top of python programming language .
#
# pandas was developed in 2008 by makinney is very useful with structured data (tabular data).

# %%
import pandas as pd
pd.read_csv()#used to read a comma separated value(csv) file into DataFrame

# %% [markdown]
# by default pandas understand the first row as column name .

# %%
pd.read_csv("file name",header=none) # no columns will be shown.

# %% [markdown]
# by default pandas provide internal integer indexes for both rows and columns.

# %%
pd.read_csv("file name",skiprows=2)#skip first two rows while reading the data

# %% [markdown]
# to read specific number of columns,rows.

# %%
pd.read_csv("file name", usecols = ['column1','column2'])

# %%
df = pd.read_csv("file name")

# %% [markdown]
# data structure is used in python which helps user to store certain values eg: lists,tuples,dictionaries etc.
#
# DataFrame: is a place or container for pandas library where we store the data in series or dataframe.
#
# series: 1Dimensional
# dataframe: 2dimensional
#
# type(df)#shows type class
# pandas.core.frame.DataFrame #output
#
# To access a particular column
#
# df.["column name"]
#
# type(df.["column name"]) = pandas.core.frame.DataFrame

# %%
import pandas as pd
l = [1,2,3,4,5]
s = pd.Series(l)
print("New generated series:",s)
# Out:
# New generated series: 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# to access the element of any series , INDEXING
s[0]
# Out:
# np.int64(1)

# %%
#slicing
s[0:3]
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# By default indexes are integers , we can have custom indexes.

# %%
d = pd.Series([100,200,300], index = ['ajay','rishabh',3])
print(d)
# Out:
# ajay       100
# rishabh    200
# 3          300
# dtype: int64

# %% [markdown]
# To see all the indexes of a series
#
# d.index
#
# To reset index
#
# d.reset_index(drop=True)
#
# multiple series forms a DataFrame.
# it consist of rows and columns.
#
# convert a series into DataFrame
#
# pd.DataFrame()

# %% [markdown]
# TO ACCESS ONLY THE FIRST 5 ROWS ON SPEICFIC NO. OF ROWS IN A DATAFRAME:
# df.head()
#
# df.tail() will give last five rows.
#
# to know no. of rows and columns present
#
# df.shape [total no. of columns and rows]
#
# df.columns [how many no. of a columns]
#
# to convert columns of dataframe into a list
#
# list(df.columns)
#
# to excess any random row
# df.sample(no. of random rows you want to access)
#
# analysis of data
#
# no. of columns/rows
#
# df.head(),
# df.tail(),
# df.sample()
#
# checking data type
#
# df.info() [function]  object=string mixed data type column = string
#
# df.dtypes  [directly gets the data type]

# %%
s = pd.Series([2,3,4],index = [ 100,"ojal","orange"])
s
# Out:
# 100       2
# ojal      3
# orange    4
# dtype: int64

# %%
df1 = pd.DataFrame(s)
df1
# Out:
#         0
# 100     2
# ojal    3
# orange  4

# %%
# to make a new column
df1["new_column"] = "200"
df1
#however the best way to access a column is illustrated as follows:-
#d.["new_column name"]
#but if it is a continous string(variable name) then we can also use df.name of column
# Out:
#         0 new_column
# 100     2        200
# ojal    3        200
# orange  4        200

# %% [markdown]
# new column element should be equal to number of original rows.
#
# column name
#
# df.column , change column names
#
# df.columns['col1','col2','col3']
#
# #reset index
# df.reset_index() if we dont provide drop = True the original index will be a column and there will be a new index.
#
# if you dont want original index to be a column name.
#
# df.reset_index(drop=True), accessing one column
#
# df["column name"]
#
# to access two column : df["column name1","column name 2","column name 3"] also known as subset of DataFrame
#
# accessing one column ie series accessing multiple columns with square []
# becomes a dataframe.

# %%
#subset of dataframe
df_subset = df[["columns name1","column name2"]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-10ffff73d641> in <cell line: 0>()
#       1 #subset of dataframe
# ----> 2 df_subset = df[["columns name1","column name2"]]
#
# NameError: name 'df' is not defined

# %% [markdown]
# Their can be excel file as well , to read an excel file
#
# pd.read_excel("name of the file with its extention ie xlsx")
#
# different functions of pandas are:-
#
# df.columns,df.dtypes,df.shape,df.info()
#
# to access a data from an online resources or from drive eg Github
#
# to read data from a html file
#
# url = pd.read_html("location or path of the html data")
# to install pip install lxml
#
# df4 = name of variable
#
# convert html file into csv file
#
# df4.to_csv("name of the file to get it save in as.csv",index = false)
#
# READ THE DATA FROM URL
# url = "location or path of the url"
# pd.read_json()url
#
# requests library:
# import requests
# data = requests.get(url)
#
# <response [200]> -> correct
# now convert it into a json file
#
# data.json()
#
# df.describe()  describe function it shows statistical information about numerical column .
#
# data is of two types
#
# > numerical (quantitative)
#
# > categorical (qualitative)
#
# continous column (float values, or decimal values)
#
# numerical , discrete data (integer value or finite value)
#
# 5 point summary is min value,max vaule,25 %, 50%,75% (% = percentile)
#
# to fetch column names (specifically which we want like object)
#
# df.dtypes == "object"
#
# df.dtypes[df.dtypes == "object"]
#
# returns those series value where condition is true .
# to get the index
#
# df.dtypes[df.dtypes == "object"].index
#
# if we only want a particular type of data. to fetch string data from the dataframe.
#
# df[df.dtypes[df.dtypes == 'object']].index
#
# for numerical data change condition to != "object"
#
# if we want to see both numerical and categorical data together
#
# df.describe(include ="all")
#
# if we want to know the info that is specific to categorical data for numerical data for this
#
# df.astype("object").describe()
#
# gives statistical information considering categorical column.
#
# df.categorical(df['column name'])   different category of column name
#
# df.[df["age"] < 18]
#
# len(df.[df["age"] < 18])
#
# to check unique values of column
#
# df.['column name'].unique()
#
# to count the number of unique values , df['column name'].nunique() this is done to get the number of values occured or repetition amount to get no. of vaules of a unique value
#
# df['column name'].value_counts(), how many times a value in the column has occured.
#
# to retrive the ABOVE data in percentage:-
#
# df["column name"].value_counts(normalize = True) * 100
#
# steps in analysis of data are
#
# 1. access the column : df.column_name , df['column_name']
#
# 2. Give the condition
#
# 3. make it a dataframe
#
# 4. use len()

# %%
import pandas as pd
stats = pd.read_csv("/content/cricket stats.csv")
df1 = pd.DataFrame(stats)
df1.set_index("Matches played")
# Out:
#                                 Players  Runs (socred)  Batting average  \
# Matches played
# 480                         VIRAT KOHLI          27500            59.37
# 730             SACHIN RAMESH TENDULKAR          34000            52.22
# 437                            JOE ROOT          21000            48.44
# 421                         STEVE SMITH          19500            51.12
# 404                     KANE WILLIAMSON          17000            54.02
# 550                          BRIAN LARA          23000            47.88
# 640                            MS DHONI          16000            44.76
# 627                         JACK KALLIS          25000            55.32
# 534                        ROHIT SHARMA          20000            50.06
# 520                        DAVID WARNER          18700            48.76
# 660                     KUMAR SANGAKARA          28200            47.80
# 325                          BABAR AZAM          18600            53.98
# ...

# %%
df1.iloc[0,3]
# Out:
# np.int64(134)

# %%
df1.head()
# Out:
#                    Players  Runs (socred)  Batting average  \
# 0              VIRAT KOHLI          27500            59.37
# 1  SACHIN RAMESH TENDULKAR          34000            52.22
# 2                 JOE ROOT          21000            48.44
# 3              STEVE SMITH          19500            51.12
# 4          KANE WILLIAMSON          17000            54.02
#
#    No. of 50sNo. Of 100s  Unnamed: 4  Strike rate  Matches played
# 0                    134          82        97.32             480
# 1                    146         100        93.33             730
# 2                     87          52        91.11             437
# 3                     74          49        93.56             421
# 4                     82          45        90.22             404

# %%
df1.tail()
# Out:
#             Players  Runs (socred)  Batting average  No. of 50sNo. Of 100s  \
# 10  KUMAR SANGAKARA          28200            47.80                    142
# 11       BABAR AZAM          18600            53.98                     87
# 12    AB DEVILLIARS          21000            52.93                     74
# 13      HASHIM AMLA          20930            49.80                     86
# 14     ALISTER COOK          17890            45.84                     57
#
#     Unnamed: 4  Strike rate  Matches played
# 10          66        93.67             660
# 11          31        88.01             325
# 12          47       100.98             465
# 13          53        92.94             490
# 14          42        90.34             387

# %%
df1[2:12] #slicing
# Out:
#             Players  Runs (socred)  Batting average  No. of 50sNo. Of 100s  \
# 2          JOE ROOT          21000            48.44                     87
# 3       STEVE SMITH          19500            51.12                     74
# 4   KANE WILLIAMSON          17000            54.02                     82
# 5        BRIAN LARA          23000            47.88                    103
# 6          MS DHONI          16000            44.76                     63
# 7       JACK KALLIS          25000            55.32                    124
# 8      ROHIT SHARMA          20000            50.06                     95
# 9      DAVID WARNER          18700            48.76                    109
# 10  KUMAR SANGAKARA          28200            47.80                    142
# 11       BABAR AZAM          18600            53.98                     87
#
#     Unnamed: 4  Strike rate  Matches played
# 2           52        91.11             437
# 3           49        93.56             421
# ...

# %%
df1.dtypes
# Out:
# Players                   object
# Runs (socred)              int64
# Batting average          float64
# No. of 50sNo. Of 100s      int64
# Unnamed: 4                 int64
# Strike rate              float64
# Matches played             int64
# dtype: object

# %%
df1.columns
# Out:
# Index(['Players', 'Runs (socred)', 'Batting average', 'No. of 50sNo. Of 100s',
#        'Unnamed: 4', 'Strike rate', 'Matches played'],
#       dtype='object')

# %%
df1['No. of 50sNo. Of 100s']
# Out:
# 0     134
# 1     146
# 2      87
# 3      74
# 4      82
# 5     103
# 6      63
# 7     124
# 8      95
# 9     109
# 10    142
# 11     87
# 12     74
# 13     86
# 14     57
# Name: No. of 50sNo. Of 100s, dtype: int64

# %%
df1.describe() # 5 point summary
# Out:
#        Runs (socred)  Batting average  No. of 50sNo. Of 100s  Unnamed: 4  \
# count      15.000000         15.00000              15.000000   15.000000
# mean    21888.000000         50.82000              97.533333   53.466667
# std      4900.720355          3.88122              28.111682   19.193997
# min     16000.000000         44.76000              57.000000   20.000000
# 25%     18650.000000         48.16000              78.000000   46.000000
# 50%     20930.000000         50.06000              87.000000   49.000000
# 75%     24000.000000         53.45500             116.500000   59.000000
# max     34000.000000         59.37000             146.000000  100.000000
#
#        Strike rate  Matches played
# count    15.000000       15.000000
# mean     94.044000      511.333333
# std       4.005598      113.673509
# min      88.010000      325.000000
# 25%      90.725000      429.000000
# 50%      93.560000      490.000000
# 75%      96.935000      588.500000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Players                15 non-null     object
#  1   Runs (socred)          15 non-null     int64
#  2   Batting average        15 non-null     float64
#  3   No. of 50sNo. Of 100s  15 non-null     int64
#  4   Unnamed: 4             15 non-null     int64
#  5   Strike rate            15 non-null     float64
#  6   Matches played         15 non-null     int64
# dtypes: float64(2), int64(4), object(1)
# memory usage: 972.0+ bytes

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.shape
# Out:
# (15, 7)

# %%
list[df1.columns]
# Out:
# list[Index(['Players', 'Runs (socred)', 'Batting average', 'No. of 50sNo. Of 100s',
#        'Unnamed: 4', 'Strike rate', 'Matches played'],
#       dtype='object')]

# %%
subset_data = df1[["Players","Runs (socred)","Batting average"]]
subset_data[0:7]
# Out:
#                    Players  Runs (socred)  Batting average
# 0              VIRAT KOHLI          27500            59.37
# 1  SACHIN RAMESH TENDULKAR          34000            52.22
# 2                 JOE ROOT          21000            48.44
# 3              STEVE SMITH          19500            51.12
# 4          KANE WILLIAMSON          17000            54.02
# 5               BRIAN LARA          23000            47.88
# 6                 MS DHONI          16000            44.76

# %%
df1.dtypes[df1.dtypes!="object"].index
# Out:
# Index(['Runs (socred)', 'Batting average', 'No. of 50sNo. Of 100s',
#        'Unnamed: 4', 'Strike rate', 'Matches played'],
#       dtype='object')

# %%
df1.dtypes[df1.dtypes=="object"].index
# Out:
# Index(['Players'], dtype='object')

# %%
df1[df1["Runs (socred)"] > 22000]
# Out:
#                     Players  Runs (socred)  Batting average  \
# 0               VIRAT KOHLI          27500            59.37
# 1   SACHIN RAMESH TENDULKAR          34000            52.22
# 5                BRIAN LARA          23000            47.88
# 7               JACK KALLIS          25000            55.32
# 10          KUMAR SANGAKARA          28200            47.80
#
#     No. of 50sNo. Of 100s  Unnamed: 4  Strike rate  Matches played
# 0                     134          82        97.32             480
# 1                     146         100        93.33             730
# 5                     103          56        88.97             550
# 7                     124          62        94.89             627
# 10                    142          66        93.67             660

# %%
len(df1[df1["Strike rate"] < 95.00])
# Out:
# 10

# %%
uni = df1["Runs (socred)"].unique()
print(uni)

var_ = df1["Runs (socred)"].nunique()
print(var_)
# Out:
# [27500 34000 21000 19500 17000 23000 16000 25000 20000 18700 28200 18600
#  20930 17890]
# 14

# %%
df1["Runs (socred)"].value_counts(normalize = True) * 100
# Out:
# Runs (socred)
# 21000    13.333333
# 27500     6.666667
# 34000     6.666667
# 19500     6.666667
# 17000     6.666667
# 23000     6.666667
# 16000     6.666667
# 25000     6.666667
# 20000     6.666667
# 18700     6.666667
# 28200     6.666667
# 18600     6.666667
# 20930     6.666667
# 17890     6.666667
# Name: proportion, dtype: float64

# %%
Data = pd.read_excel('cricket stats.xlsx')
Data
# Out:
#                     Players  Runs (socred)  Batting average  \
# 0               VIRAT KOHLI          27500            59.37
# 1   SACHIN RAMESH TENDULKAR          34000            52.22
# 2                  JOE ROOT          21000            48.44
# 3               STEVE SMITH          19500            51.12
# 4           KANE WILLIAMSON          17000            54.02
# 5                BRIAN LARA          23000            47.88
# 6                  MS DHONI          16000            44.76
# 7               JACK KALLIS          25000            55.32
# 8              ROHIT SHARMA          20000            50.06
# 9              DAVID WARNER          18700            48.76
# 10          KUMAR SANGAKARA          28200            47.80
# 11               BABAR AZAM          18600            53.98
# 12            AB DEVILLIARS          21000            52.93
# 13              HASHIM AMLA          20930            49.80
# 14             ALISTER COOK          17890            45.84
#
# ...

# %%
df1
df1.iloc[3]
# Out:
# Players                  STEVE SMITH
# Runs (socred)                  19500
# Batting average                51.12
# No. of 50sNo. Of 100s             74
# Unnamed: 4                        49
# Strike rate                    93.56
# Matches played                   421
# Name: 3, dtype: object

# %%
df1.loc[0:4] # all 5 rows will be accessed
# Out:
#                    Players  Runs (socred)  Batting average  \
# 0              VIRAT KOHLI          27500            59.37
# 1  SACHIN RAMESH TENDULKAR          34000            52.22
# 2                 JOE ROOT          21000            48.44
# 3              STEVE SMITH          19500            51.12
# 4          KANE WILLIAMSON          17000            54.02
#
#    No. of 50sNo. Of 100s  Unnamed: 4  Strike rate  Matches played
# 0                    134          82        97.32             480
# 1                    146         100        93.33             730
# 2                     87          52        91.11             437
# 3                     74          49        93.56             421
# 4                     82          45        90.22             404

# %%
df2 = df1.set_index("Players")
df2
# Out:
#                          Runs (socred)  Batting average  \
# Players
# VIRAT KOHLI                      27500            59.37
# SACHIN RAMESH TENDULKAR          34000            52.22
# JOE ROOT                         21000            48.44
# STEVE SMITH                      19500            51.12
# KANE WILLIAMSON                  17000            54.02
# BRIAN LARA                       23000            47.88
# MS DHONI                         16000            44.76
# JACK KALLIS                      25000            55.32
# ROHIT SHARMA                     20000            50.06
# DAVID WARNER                     18700            48.76
# KUMAR SANGAKARA                  28200            47.80
# BABAR AZAM                       18600            53.98
# AB DEVILLIARS                    21000            52.93
# HASHIM AMLA                      20930            49.80
# ALISTER COOK                     17890            45.84
#
# ...

# %%
df2.loc[['VIRAT KOHLI','STEVE SMITH','KANE WILLIAMSON','JOE ROOT']]
# Out:
#                  Runs (socred)  Batting average  No. of 50sNo. Of 100s  \
# Players
# VIRAT KOHLI              27500            59.37                    134
# STEVE SMITH              19500            51.12                     74
# KANE WILLIAMSON          17000            54.02                     82
# JOE ROOT                 21000            48.44                     87
#
#                  Unnamed: 4  Strike rate  Matches played
# Players
# VIRAT KOHLI              82        97.32             480
# STEVE SMITH              49        93.56             421
# KANE WILLIAMSON          45        90.22             404
# JOE ROOT                 52        91.11             437

# %%
l = list(subset_data)
print(l)
# convert the following into series
s = pd.Series(l)
print("converting list into series:\n",s)
# Out:
# ['Players', 'Runs (socred)', 'Batting average']
# converting list into series:
#  0            Players
# 1      Runs (socred)
# 2    Batting average
# dtype: object

# %%
df1["Batting average"]
# Out:
# 0     59.37
# 1     52.22
# 2     48.44
# 3     51.12
# 4     54.02
# 5     47.88
# 6     44.76
# 7     55.32
# 8     50.06
# 9     48.76
# 10    47.80
# 11    53.98
# 12    52.93
# 13    49.80
# 14    45.84
# Name: Batting average, dtype: float64

# %%
s = pd.Series(df1['Batting average'])
print(s)
s1 = pd.Series(df1['Strike rate'])
print(s1)
# Out:
# 0     59.37
# 1     52.22
# 2     48.44
# 3     51.12
# 4     54.02
# 5     47.88
# 6     44.76
# 7     55.32
# 8     50.06
# 9     48.76
# 10    47.80
# 11    53.98
# 12    52.93
# 13    49.80
# 14    45.84
# Name: Batting average, dtype: float64
# 0      97.32
# 1      93.33
# 2      91.11
# 3      93.56
# 4      90.22
# 5      88.97
# 6      96.55
# 7      94.89
# 8      99.90
# 9      98.87
# 10     93.67
# 11     88.01
# 12    100.98
# 13     92.94
# 14     90.34
# Name: Strike rate, dtype: float64

# %%
sum = s + s1
print('concatenation of both the series:\n', sum)
# Out:
# concatenation of both the series:
#  0     156.69
# 1     145.55
# 2     139.55
# 3     144.68
# 4     144.24
# 5     136.85
# 6     141.31
# 7     150.21
# 8     149.96
# 9     147.63
# 10    141.47
# 11    141.99
# 12    153.91
# 13    142.74
# 14    136.18
# dtype: float64

# %%
df1.count(numeric_only=True)
# Out:
# Runs (socred)            15
# Batting average          15
# No. of 50sNo. Of 100s    15
# Unnamed: 4               15
# Strike rate              15
# Matches played           15
# dtype: int64

# %% [markdown]
# To access rows and columns of a dataframe
#
# 1 implicit/internal/integer indexing  use iloc()
#
# 2 explicit/or named indexing  loc() is used
#
# dataframe.iloc[0:3] starts from 0 and goes till 2. iloc requires numeric value only.
#
# dataframe.loc used for named indexes.
# to access few columns only.
#
# series and dataframe with different indexes cannot be concatenated using "+ symbol " if we keep the indexes same then in case of series concatenation can happen.
#
# to drop any unwanted column
#
# df.drop('column name',axis=1) keep the axis = 0 to drop row like this df.drop(1)
#
# to modify the original dataframe use inplace = True (parameter)
#
# TO reset index use df.reset_index()
#
# how to know number of null values present in a dataframe or a series
# #df.isnull().sum()
#
# in analysis either we remove the null value or we replace it with something else. also called as imputation
#
# for numerical data median and mean are used while imputation process for outlier(abnormal) value treatment use mean else median
# and for categorical  mode is used.
#
# imputation examples
#
# #df.fillna('somevalue')
#
# #df.fillna(0)
#
# df.dropna()  (it removes ALL the null values with some non null values from a dataframe. axis = 1 is to drop values from the columns.
#
# TO DROP values from one column
# #df['name of the column'].dropna(axis=1)
#
# To fill the missing value with mean value
#
# #df['column name'].fillna(df['column name'].mean()) same goes with median
# #df['column name'].fillna(df['column name'].median())
#
# other ways to fill some values are:-
#
# df.fillna(method="ffill") forwardfill next forward value will be used to fill. ffill says start from the bottom of the dataframe find nan values and replace it with succeeding value
#
# #df.fillna('bfill')
#
# backward fill is exact opposite of ffill
#
# for checking duplicate rows:
#
# #df.duplicated().sum()
#
# groupby function  df.groupby('column name').mean(numeric_only = True) statement used as numeric_only = True is an parameter that is required to be given for function to act on numeric values only.
#
# spliting of the column happens and then aggregation is done.
#
# #df.gropuby([['column name 1']['column name2'].agg([min(),max(),mean(),median(),np.std(),var(),count]))
#
# for this import numpy as np
#
# we can groupby based on two columns df.groupby(['col 1','col 2'])['col name'].sum() , convert the resultant into dataframe by using to_frame() after sum()
#
# #unstack()
# is similar to transpose function.

# %% [markdown]
# Different functions in pandas :-
# #concat()
# concatenation means keeping two separate dataframes together horizontally and vertically both
#
# #pd.concat()
# default axis = 0 , it concatenates pandas dataframe/series along a particular axis
#
# for horizontal concatenation axis = 1 along the columns
#
# for vertical concatenation axis = 0 along the rows
#
# #merge()
# merege function where merging two dataframe is based on a common column ie inner merge  syntax for the same is
# #pd.merge(df1,df2,how='inner')
#
# similarly there is outer parameter that includes all the elements in both the dataframe. how='outer' (parameter)
#
# then their is right merge where all the elements from the right dataframe will be included + all the common elements other dataframe that is to be merged.
# #pd.merge(df1,df2,how='right')
#
# same is case with left merge parameter
# #pd.merge(df1,df2,how='left')
#
# cross merge it shows every permutation and combination of rows which can be possible.  parameter how='cross'
#
# when we dont want to use any common column for merging the data we use
#
# #pd.merge(df1,df2,how='left',left_on='column name',right_on='column name')
# and since the merging is happening on a non common column in this case common column will have different names.
#
# join() works based on index whereas merge() works based on columns
#
# join() here based on common index (intersection) will be performed
# #df1.join(df2,how='inner')
# similar with outer
#
# left join
# all the elements of left dataframe and elements having common index as left dataframe will be displayed.
#
# similar is the case with right join
# #df1.join(df2,how='right')
#
# apply function to apply function on all the elements/values of a column
#
# #df['column namw']=df['column name'].apply(lambda x:x*90)
#
# to get the length of all values of a particular column
# #df['column namw']=df['column name'].apply(len)
#
# user defined functions can be used inside apply() just pass the function instead of calling it.
#
# reindex makes new index for series or dataframe
# #df.reindex()
#
# for sorting values
# #df.sort_values(by='column name')
#
# concepts of date time and functions associated with strings column
#
# Pandas have an options system that lets you customize some aspects of its behavior, display-related options being those the user is most likely to adjust.
#
# pd.set_option("display.max_colwidth",1000) different parameter
# max_columns
# max_rows
#
# no. of words
# #len(variable.split())
# no. of words will be shown
#
# in dataframe
#
# #df['column name']= df1['column name'].apply(lambda x: len(x.split()))
# this will give no. of words
#
# #string functions
# to change characters of a string into lower case
#
# #variable['column name'].str.lower()
# similarly upper() for uppercase
#
# and startswith() to find whether the string starts with the parameter given by the user.
#
# DIFFERENT MATHEMATICAL FUNCTIONS ON PANDAS
#
# multiply all the columns with 5
#
# #df['column name']*5
# df['column name'].mean()
# df['column name'].max(),var()
#
# average of consecutive 2 no.s
# #df.rolling(window=2).mean()
# first will be nan as their is no prior/pervious element to it.
# in case of 3 first 2 will ne nan and so on. depending upon the various parameter given.
#
# #df.rolling(window=2).sum()/min()/max()
# #type casting
# df['column name'].astype(int)
# changes the data type of the column
# #df['column name'] = np.random.choice(['a','b'],size= whatever is size of each column of the df)
#
# df.groupby('column name')['column name'].sum()
#
# gropuby function with rolling sum
# #df.groupby('column name')['column name'].rolling(window=2).sum()
#
# for cumulative sum
# #df.cumsum()
# Date time concept
#
# pd.to_datetime(df['column name']) it is possible on that column that has values which can be used in this type(related to time or years/month/date)
#
# type class is datetime64[ns]
#
# #df['column name'].dt.year/dt.month/dt.day
#
# #pd.date_range(start='year-month-date',end='year-month-date',freq='D')
# generates daily data for hourly change the freq='H'
# pd.timestamp.now()  current time will be given
#
# to check execution/run time of a code
# 1.
# import time
# start=time.time()
# start
# for i in range(1000):
#     pass
# end=time.time()
# print(end-start)
#
# 2.
# start=pd.timestamp.now()
# for i in range(1000):
#     pass
# end=pd.timestamp.now()
# print(end-start)
#
#
# 3.
# import time
# start=time.perf_counter()
# for i in range(1000):
#     pass
# end= time.perf_counter()

# %%
import time
start=time.perf_counter()
for i in range(1000):
    pass
end= time.perf_counter()
print(end-start)
# Out:
# 0.0001658350000042219

# %%
import pandas as pd
pd.date_range(start='2025-02-24',end='2025-11-15',freq='D')
# Out:
# DatetimeIndex(['2025-02-24', '2025-02-25', '2025-02-26', '2025-02-27',
#                '2025-02-28', '2025-03-01', '2025-03-02', '2025-03-03',
#                '2025-03-04', '2025-03-05',
#                ...
#                '2025-11-06', '2025-11-07', '2025-11-08', '2025-11-09',
#                '2025-11-10', '2025-11-11', '2025-11-12', '2025-11-13',
#                '2025-11-14', '2025-11-15'],
#               dtype='datetime64[ns]', length=265, freq='D')

# %%
len(pd.date_range(start='2025-02-24',end='2025-11-15',freq='D'))
# Out:
# 265

# %%
# to know exact date and time before 1 week
_diff = pd.Timestamp.now() - pd.DateOffset(weeks=1)
_diff
# Out:
# Timestamp('2025-05-13 07:54:48.242141')

# %%
#pandas also has the option to have all the stock prices
# !pip install yfinance

# %%
import yfinance as yf
data2 = yf.download('GOOG',start='2024-04-01',end='2025-03-31')
data2
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
# ...

# %%
#resample
data2['High'].resample('M').mean()
# Out:
# <ipython-input-13-b9204e5f3e79>:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data['High'].resample('M').mean()
# Ticker            GOOG
# Date
# 2024-04-30  159.621505
# 2024-05-31  173.792567
# 2024-06-30  179.892529
# 2024-07-31  183.709626
# 2024-08-31  166.740440
# 2024-09-30  160.878012
# 2024-10-31  168.543814
# 2024-11-30  176.122166
# 2024-12-31  190.212016
# 2025-01-31  198.731493
# 2025-02-28  188.197432
# 2025-03-31  170.334105

# %%
data2.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# To plot one column only
data2['Low'].plot(kind='line') # this is used for time series data or to know the trend
# Out:
# <Axes: xlabel='Date'>

# %%
data2['Low'].plot(kind='hist') # used for continous data is ther
# Out:
# <Axes: ylabel='Frequency'>

# %%
data2['Low'].plot(kind='bar') ##used for categorical data
# Out:
# <Axes: xlabel='Date'>

# %%
#to get scatter plot
data2.plot(x='High',y='Low',kind='scatter') # this is used to understand the relationship between 2 variables
# Out:
# <Axes: xlabel='High', ylabel='Low'>

# %%
data2
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
# 2025-03-28  156.059998  163.809998  155.339005  162.360001  34866500
#
# [250 rows x 5 columns]

# %%
data2.drop('Low',axis=1)
# Out:
# Price            Close        High        Open    Volume
# Ticker            GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  151.114240  24469800
# 2024-04-02  155.135208  155.254653  154.020493  17598100
# 2024-04-03  155.632858  155.812018  154.189697  17266200
# 2024-04-04  151.223724  155.443726  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.964954  16289800
# ...                ...         ...         ...       ...
# 2025-03-24  169.929993  170.500000  169.264999  18742800
# 2025-03-25  172.789993  172.910004  171.179993  13841600
# 2025-03-26  167.139999  171.940002  171.300003  22498000
# 2025-03-27  164.080002  167.440002  166.710007  21571200
# 2025-03-28  156.059998  163.809998  162.360001  34866500
#
# [250 rows x 4 columns]

# %%
data2.reset_index()
# Out:
# Price        Date       Close        High         Low        Open    Volume
# Ticker                   GOOG        GOOG        GOOG        GOOG      GOOG
# 0      2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 1      2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2      2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 3      2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 4      2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ..            ...         ...         ...         ...         ...       ...
# 244    2025-03-21  166.250000  166.470001  163.029999  163.380005  29882100
# 245    2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 246    2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 247    2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# ...

# %%
data2.dropna()
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-21  166.250000  166.470001  163.029999  163.380005  29882100
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
#
# [249 rows x 5 columns]

# %%
data2.isnull().sum()
# Out:
# Price   Ticker
# Close   GOOG      0
# High    GOOG      0
# Low     GOOG      0
# Open    GOOG      0
# Volume  GOOG      0
# dtype: int64

# %%
data2['Open'].dropna(axis=1)
# Out:
# Ticker            GOOG
# Date
# 2024-04-01  151.114240
# 2024-04-02  154.020493
# 2024-04-03  154.189697
# 2024-04-04  154.348921
# 2024-04-05  150.964954
# ...                ...
# 2025-03-21  163.380005
# 2025-03-24  169.264999
# 2025-03-25  171.179993
# 2025-03-26  171.300003
# 2025-03-27  166.710007
#
# [249 rows x 1 columns]

# %%
Date = pd.date_range(start='2024-04-01',end='2024-12-05')
data2['Date'] = Date
data2
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-21  166.250000  166.470001  163.029999  163.380005  29882100
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
#
# Price            Date
# Ticker
# Date
# 2024-04-01 2024-04-01
# ...

# %%
data2['Date'].dt.year
# Out:
# Date
# 2024-04-01    2024
# 2024-04-02    2024
# 2024-04-03    2024
# 2024-04-04    2024
# 2024-04-05    2024
#               ...
# 2025-03-21    2024
# 2025-03-24    2024
# 2025-03-25    2024
# 2025-03-26    2024
# 2025-03-27    2024
# Name: Date, Length: 249, dtype: int32

# %%
import numpy as np
new_column = np.random.choice(['A','B','C','D'],size=249)
data2['new_column'] = new_column
data2
# Out:
# Price            Close        High         Low        Open    Volume  \
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-21  166.250000  166.470001  163.029999  163.380005  29882100
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
#
# Price            Date new_column
# Ticker
# Date
# ...

# %%
data2.groupby('new_column')['Open'].rolling(window=2).sum()
# Out:
# Ticker                       GOOG
# new_column Date
# A          2024-04-04         NaN
#            2024-04-05  305.313875
#            2024-04-08  304.253902
#            2024-04-11  310.882514
#            2024-04-23  315.435956
# ...                           ...
# D          2025-03-18  334.430008
#            2025-03-20  329.785004
#            2025-03-21  327.205002
#            2025-03-24  332.645004
#            2025-03-27  335.975006
#
# [249 rows x 1 columns]

# %%
data2["High"].cumsum()
# Out:
# Ticker              GOOG
# new_column
# B             156.259865
# C             311.514518
# C             467.326536
# A             622.770262
# A             776.880323
# ...                  ...
# D           43184.395897
# D           43354.895897
# C           43527.805900
# A           43699.745903
# D           43867.185905
#
# [249 rows x 1 columns]

# %%
import pandas as pd
data1 = [['Alice', 24], ['Bob', 30], ['Charlie', 22]]
df = pd.DataFrame(data1, columns=['Name', 'Age'])
print(df)
# Out:
#       Name  Age
# 0    Alice   24
# 1      Bob   30
# 2  Charlie   22

# %%
_split = df['Name'].apply(lambda x: len(x.split()))
# Assign the result to a new column in the DataFrame df
df['_split'] = _split

print(df)
# Out:
#       Name  Age  _split
# 0    Alice   24       1
# 1      Bob   30       1
# 2  Charlie   22       1

# %%
data2
# Out:
# Price            Close        High         Low        Open    Volume
# Ticker            GOOG        GOOG        GOOG        GOOG      GOOG
# Date
# 2024-04-01  155.762222  156.259865  150.935080  151.114240  24469800
# 2024-04-02  155.135208  155.254653  152.736581  154.020493  17598100
# 2024-04-03  155.632858  155.812018  153.405417  154.189697  17266200
# 2024-04-04  151.223724  155.443726  151.164010  154.348921  24184800
# 2024-04-05  153.214310  154.110061  150.368779  150.964954  16289800
# ...                ...         ...         ...         ...       ...
# 2025-03-24  169.929993  170.500000  167.440002  169.264999  18742800
# 2025-03-25  172.789993  172.910004  170.550003  171.179993  13841600
# 2025-03-26  167.139999  171.940002  166.860992  171.300003  22498000
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200
# 2025-03-28  156.059998  163.809998  155.339005  162.360001  34866500
#
# [250 rows x 5 columns]

# %%
data2['Low'].astype(int)
# Out:
# Ticker      GOOG
# Date
# 2024-04-01   150
# 2024-04-02   152
# 2024-04-03   153
# 2024-04-04   151
# 2024-04-05   150
# ...          ...
# 2025-03-24   167
# 2025-03-25   170
# 2025-03-26   166
# 2025-03-27   163
# 2025-03-28   155
#
# [250 rows x 1 columns]

# %%
data2.rolling(window=2).min()
# Out:
# Price            Close        High         Low        Open      Volume
# Ticker            GOOG        GOOG        GOOG        GOOG        GOOG
# Date
# 2024-04-01         NaN         NaN         NaN         NaN         NaN
# 2024-04-02  155.135208  155.254653  150.935080  151.114240  17598100.0
# 2024-04-03  155.135208  155.254653  152.736581  154.020493  17266200.0
# 2024-04-04  151.223724  155.443726  151.164010  154.189697  17266200.0
# 2024-04-05  151.223724  154.110061  150.368779  150.964954  16289800.0
# ...                ...         ...         ...         ...         ...
# 2025-03-24  166.250000  166.470001  163.029999  163.380005  18742800.0
# 2025-03-25  169.929993  170.500000  167.440002  169.264999  13841600.0
# 2025-03-26  167.139999  171.940002  166.860992  171.179993  13841600.0
# 2025-03-27  164.080002  167.440002  163.850006  166.710007  21571200.0
# 2025-03-28  156.059998  163.809998  155.339005  162.360001  21571200.0
#
# [250 rows x 5 columns]

# %%
data2['Open'].median()
# Out:
# Ticker
# GOOG    172.238784
# dtype: float64
