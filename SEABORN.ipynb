# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Seaborn
# Defination
#
# seaborn is python data visualisation library base on matplotlib. it provides high level of interface for drawing attractive and informative statistical graphics.
#
# #Advantages of seaborn
# more attractive plots
#
# more options available

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# some basic pandas operations
df.shape
# Out:
# (244, 7)

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.count(axis=0)
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %% [markdown]
# # To plot numerical values in seaborn
# seaborn.relplot has options of plotting both categorical and numerical data and shows the relationship between 2 variables. also called as relationship plot
#
# by default relplot makes scatter plot
#
# to make line plot use parameter kind = 'line'

# %%
sns.relplot(x='total_bill',y='tip',data = df)

# %%
''' now for more analysis we use a parameter called hue , hue is used for segregation or distinguish
between some category for eg smoker, non smoker. it also gives different color coding for the
column passed.'''

sns.relplot(x='total_bill',y='tip',data = df,hue='smoker')

# %%
# to see the size or to know how many peoples are their
sns.relplot(x='total_bill',y='tip',data = df,hue='size')

# %%
''' for more better understanding or to draw more clear insights from the data use style inplace of hue.
it gives different representation of a column value. '''
sns.relplot(x='total_bill',y='tip',data = df,style='size')

# %%
sns.relplot(x='total_bill',y='tip',data = df,style='smoker',hue='sex')
''' insights can be drawn from this graph for eg the most amount of tip was given by
a male who is a smoker also as the amount of bill increases the tip amount also increases.'''
# Out:
# ' insights can be drawn from this graph for eg the most amount of tip was given by\na male who is a smoker also as the amount of bill increases the tip amount also increases.'

# %% [markdown]
# #line plot using relplot in seaborn
# by giving parameter kind = 'line'
#
# line chart is used for data having time component and also to understand the trend in data.

# %%
# to make a line chart using relplot
time = np.arange(500)
value = np.random.randint(500,size=500).cumsum()
df1 = pd.DataFrame({'time':time,'value':value})
df1
# Out:
#      time   value
# 0       0     254
# 1       1     286
# 2       2     534
# 3       3     961
# 4       4    1175
# ..    ...     ...
# 495   495  121721
# 496   496  122047
# 497   497  122444
# 498   498  122879
# 499   499  123047
#
# [500 rows x 2 columns]

# %%
sns.relplot(x='time',y='value',data = df1,kind='line',sort=True)

# %%
# by taking another example
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('fmri')
fmri = sns.load_dataset('fmri')
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(x='timepoint',y='signal',data =fmri,kind='line')

# %% [markdown]
# the shaded region in the output shows that the data point at a particular point can fall between the shaded area around it.
# confidence interval is its another name .

# %%
sns.relplot(x='timepoint',y='signal',data =fmri,kind='line',ci=None) #  to remove confidence interval we used parameter ci = None

# %% [markdown]
# not to have confidence interval use parameter
#
# estimator=None

# %%
sns.relplot(x='timepoint',y='signal',data =fmri,kind='line',estimator=None)

# %%
# now use of different parameters for better analysis
sns.relplot(x='timepoint',y='signal',data =fmri,kind='line',hue='event',style='region',dashes = False,marker='o')
# to remove dashes we used parameter dashes = False

# %%
''' further more
to make subplots based on columns '''
df3 =sns.load_dataset('planets')
df3
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
sns.relplot(x='distance',y='year',data=df3,hue='year',col='method')

# %% [markdown]
# #categorical data plots

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.catplot(x='total_bill',y='sex',data=df)

# %%
''' in catplot few data points are overlapping to see it separately or
to avoid it use swarm plot '''
sns.catplot(x='total_bill',y='sex',data=df,kind='swarm',color="darkgreen")

# %%
# to see outliers
sns.catplot(x='total_bill',y='sex',data=df,kind='box',color='skyblue')

# %%
sns.catplot(x='total_bill',y='sex',data=df,kind='violin',color='violet')

# %%
#Barplot
sns.barplot(x='day',y='total_bill',data=df,color='orange')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
''' to understand distribution of 2 data's
1 column = univariate
2 column = bivariate
to dram bivariate plot'''
sns.jointplot(x='total_bill',y='tip',data=df,color='red')

# %% [markdown]
# jointplot understand the relationship and also distribution of 2 variables.
#
# to see it in line chart use parameter kind = 'reg'

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg',color='purple')

# %% [markdown]
# The line depicted is called kernel density estimator (ked) it talks about the density of data for different presentation.

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex',color='yellow')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='kde',color='blue')
# the pattern displayed in the output below contour plot

# %% [markdown]
# to make plot (scatter plot) with respect to all numerical columns.

# %%
sns.pairplot(df,palette='rainbow',hue='sex')
''' all the diagonal plots will be histogram which are univariated '''
# Out:
# ' all the diagonal plots will be histogram which are univariated '

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.boxplot(x='tip',y='total_bill',data=df,hue='size',orient='h')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
# to segregate all numeric columns
data1 = df[['total_bill','size','tip']]
data1
# Out:
#      total_bill  size   tip
# 0         16.99     2  1.01
# 1         10.34     3  1.66
# 2         21.01     3  3.50
# 3         23.68     2  3.31
# 4         24.59     4  3.61
# ..          ...   ...   ...
# 239       29.03     3  5.92
# 240       27.18     2  2.00
# 241       22.67     2  2.00
# 242       17.82     2  1.75
# 243       18.78     2  3.00
#
# [244 rows x 3 columns]

# %%
# correlation is relationship between 2 variables and their impact on each other
data1.corr()
# Out:
#             total_bill      size       tip
# total_bill    1.000000  0.598315  0.675734
# size          0.598315  1.000000  0.489299
# tip           0.675734  0.489299  1.000000

# %%
''' heatmap = value encoded with different colors
this can be viewed or presented as plot. '''
sns.heatmap(data1.corr(),annot=True,cmap='rainbow')
# by using parameter to see annot = True correlation values.
# Out:
# <Axes: >

# %%
sns.countplot(x='sex',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x='total_bill',y='tip',data=df,hue='sex',palette='rainbow') # it gives regrssion line

# %%
''' to increase the height use parameter
height=50
to control aspect use aspect=0.5'''
sns.lmplot(x='total_bill',y='tip',data=df,hue='sex',palette='rainbow',height=10,aspect=1)
